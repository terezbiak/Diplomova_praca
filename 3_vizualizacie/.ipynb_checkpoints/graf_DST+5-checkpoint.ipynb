# %% [markdown]
# # Graf pre DST+5
#
# Notebook porovnava nove kontinualne a event experimenty pre horizont DST+5 v zadanom casovom okne.

# %%
from pathlib import Path

from viz_nove_experimenty import (
    OUTPUT_ROOT,
    plot_continuous_vs_event_window,
    save_continuous_summary_csv,
    save_event_summary_csv,
    summarize_continuous_predictions,
    summarize_event_predictions,
)

# %%
continuous_variant = "DST+BZ_GSM+V"
event_feature_key = "dst_bz_v"
start_date = "2024-12-31"
end_date = "2025-01-03"
horizon_hours = 5

output_dir = OUTPUT_ROOT / "graf_DST+5"
output_dir.mkdir(parents=True, exist_ok=True)
output_dir
# Out:
# PosixPath('/home/jovyan/data/lightning/TereziaD/DP_pokracovanieBP/DP_Drengubiakova_Terezia_1/3_vizualizacie/vystupy_nove_data/graf_DST+5')

# %%
continuous_summary = summarize_continuous_predictions(continuous_variant)
event_summary = summarize_event_predictions()

continuous_csv = None
event_csv = None
if not continuous_summary.empty:
    continuous_csv = save_continuous_summary_csv(continuous_summary, output_dir)
if not event_summary.empty:
    event_csv = save_event_summary_csv(event_summary, output_dir)

plot_path = output_dir / f"continuous_vs_event_DST+{horizon_hours}.png"
plot_continuous_vs_event_window(
    continuous_variant=continuous_variant,
    event_feature_key=event_feature_key,
    horizon_hours=horizon_hours,
    start_date=start_date,
    end_date=end_date,
    output_path=plot_path,
)

print(f"Output directory: {output_dir}")
print(f"Plot: {plot_path}")
print(f"Continuous summary CSV: {continuous_csv}")
print(f"Event summary CSV: {event_csv}")

if not continuous_summary.empty:
    display(
        continuous_summary[continuous_summary["horizon_hours"] == horizon_hours]
        .sort_values(["lookback_hours"])
        .reset_index(drop=True)
    )
if not event_summary.empty:
    display(
        event_summary[event_summary["horizon_hours"] == horizon_hours]
        .sort_values(["feature_key", "lookback_hours"])
        .reset_index(drop=True)
    )
# Out:
# Output directory: /home/jovyan/data/lightning/TereziaD/DP_pokracovanieBP/DP_Drengubiakova_Terezia_1/3_vizualizacie/vystupy_nove_data/graf_DST+5
# Plot: /home/jovyan/data/lightning/TereziaD/DP_pokracovanieBP/DP_Drengubiakova_Terezia_1/3_vizualizacie/vystupy_nove_data/graf_DST+5/continuous_vs_event_DST+5.png
# Continuous summary CSV: /home/jovyan/data/lightning/TereziaD/DP_pokracovanieBP/DP_Drengubiakova_Terezia_1/3_vizualizacie/vystupy_nove_data/graf_DST+5/continuous_summary_metrics.csv
# Event summary CSV: /home/jovyan/data/lightning/TereziaD/DP_pokracovanieBP/DP_Drengubiakova_Terezia_1/3_vizualizacie/vystupy_nove_data/graf_DST+5/event_summary_metrics.csv
#         variant  horizon_hours  lookback_hours    rows  mae_persistence  \
# 0  DST+BZ_GSM+V              5               6  194185         6.683642
# 1  DST+BZ_GSM+V              5              12  194179         6.683663
# 2  DST+BZ_GSM+V              5              18  194173         6.683684
# 3  DST+BZ_GSM+V              5              24  194167         6.683360
#
#    mae_lstm  mae_hybrid  rmse_persistence  rmse_lstm  rmse_hybrid  \
# 0  5.802350    5.993286         10.677962   9.090739     9.319422
# 1  5.827393    6.147841         10.678037   8.966333     9.367546
# 2  5.678605    5.995253         10.678112   8.893458     9.312135
# 3  5.635629    5.879409         10.677735   8.848053     9.192500
#
#                                                 path  precision_m20  \
# 0  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.786836
# 1  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.779768
# 2  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.786301
# 3  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.802176
#
#    recall_m20    f1_m20  precision_m50  recall_m50    f1_m50
# 0    0.720443  0.752178       0.701844    0.657815  0.679117
# 1    0.721227  0.749356       0.697341    0.649617  0.672633
# 2    0.726971  0.755473       0.724599    0.627874  0.672778
# 3    0.720946  0.759395       0.718099    0.632864  0.672793
#    feature_key  lookback_hours  horizon_hours   rows  mae_persistence  \
# 0       dst_bz               6              5  22676        11.559358
# 1       dst_bz              12              5  21818        11.749244
# 2       dst_bz              18              5  20960        11.952624
# 3       dst_bz              24              5  20102        12.158989
# 4     dst_bz_v               6              5  22676        11.559358
# 5     dst_bz_v              12              5  21818        11.749244
# 6     dst_bz_v              18              5  20960        11.952624
# 7     dst_bz_v              24              5  20102        12.158989
# 8     dst_only               6              5  22676        11.559358
# 9     dst_only              12              5  21818        11.749244
# 10    dst_only              18              5  20960        11.952624
# 11    dst_only              24              5  20102        12.158989
# 12       dst_v               6              5  15090        11.853744
# 13       dst_v              12              5  20068        11.674507
# 14       dst_v              18              5  18428        11.960115
# 15       dst_v              24              5  16757        12.206063
#
#     mae_bilstm  mae_bilstm_gp  rmse_persistence  rmse_bilstm  rmse_bilstm_gp  \
# 0    10.200822      10.434634         18.566598    16.372210       16.229233
# 1    10.193175      10.688879         18.841618    16.317147       16.822248
# 2    10.347697      10.809293         19.133399    16.737349       16.777774
# 3    10.693457      10.638244         19.434744    17.577784       16.884113
# 4    10.233172      10.525011         18.566598    16.394540       16.276030
# 5    10.187959      10.413785         18.841618    16.198321       16.135219
# 6    10.173185      10.489366         19.133399    16.325362       16.290897
# 7    10.433917      10.575318         19.434744    16.840365       16.683347
# 8    10.526770      10.907623         18.566598    16.802951       17.243300
# 9    10.453301      11.174265         18.841618    16.912158       17.665741
# 10   10.739636      11.141589         19.133399    17.319476       17.508923
# 11   10.859099      11.338800         19.434744    17.772110       17.865058
# 12   10.795782      11.015709         18.960310    17.797094       17.405220
# 13   10.752389      10.958670         18.603939    17.140545       17.310006
# 14   10.777866      11.048159         19.032781    17.282387       17.257136
# 15   10.746327      10.945258         19.398936    17.601396       17.316996
#
#                                                  path  precision_m20  \
# 0   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.858367
# 1   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.890204
# 2   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.894959
# 3   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.896042
# 4   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.859892
# 5   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.874912
# 6   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.898553
# 7   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.870756
# 8   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.880403
# 9   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.890228
# 10  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.890856
# 11  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.889291
# 12  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.866550
# 13  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.887139
# 14  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.894096
# 15  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.873339
#
#     recall_m20    f1_m20  precision_m50  recall_m50    f1_m50
# 0     0.954758  0.904000       0.843436    0.601957  0.702524
# 1     0.919249  0.904493       0.761556    0.655435  0.704522
# 2     0.919182  0.906909       0.755187    0.672609  0.711510
# 3     0.929603  0.912514       0.781679    0.643696  0.706009
# 4     0.949648  0.902544       0.837870    0.608913  0.705275
# 5     0.941043  0.906773       0.804348    0.643478  0.714976
# 6     0.925105  0.911635       0.750474    0.687826  0.717786
# 7     0.958999  0.912750       0.825588    0.641087  0.721733
# 8     0.915187  0.897458       0.745736    0.627391  0.681464
# 9     0.916415  0.903132       0.745561    0.638913  0.688129
# 10    0.926315  0.908239       0.762516    0.645652  0.699235
# 11    0.934180  0.911183       0.754115    0.637391  0.690858
# 12    0.948627  0.905733       0.835458    0.633382  0.720520
# 13    0.926227  0.906261       0.745493    0.660876  0.700639
# 14    0.927146  0.910321       0.751840    0.676763  0.712329
# 15    0.961665  0.915376       0.819308    0.634999  0.715474

# %%
sorted(path.name for path in Path(output_dir).glob("*"))
# Out:
# ['continuous_summary_metrics.csv',
#  'continuous_vs_event_DST+5.png',
#  'event_summary_metrics.csv']
