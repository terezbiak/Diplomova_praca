# %% [markdown]
# # Graf pre DST+4
#
# Notebook porovnava nove kontinualne a event experimenty pre horizont DST+4 v zadanom casovom okne.

# %%
from pathlib import Path

from viz_nove_experimenty import (
    OUTPUT_ROOT,
    plot_continuous_vs_event_window,
    save_continuous_summary_csv,
    save_event_summary_csv,
    summarize_continuous_predictions,
    summarize_event_predictions,
)

# %%
continuous_variant = "DST+BZ_GSM+V"
event_feature_key = "dst_bz_v"
start_date = "2024-12-31"
end_date = "2025-01-03"
horizon_hours = 4

output_dir = OUTPUT_ROOT / "graf_DST+4"
output_dir.mkdir(parents=True, exist_ok=True)
output_dir
# Out:
# PosixPath('/home/jovyan/data/lightning/TereziaD/DP_pokracovanieBP/DP_Drengubiakova_Terezia_1/3_vizualizacie/vystupy_nove_data/graf_DST+4')

# %%
continuous_summary = summarize_continuous_predictions(continuous_variant)
event_summary = summarize_event_predictions()

continuous_csv = None
event_csv = None
if not continuous_summary.empty:
    continuous_csv = save_continuous_summary_csv(continuous_summary, output_dir)
if not event_summary.empty:
    event_csv = save_event_summary_csv(event_summary, output_dir)

plot_path = output_dir / f"continuous_vs_event_DST+{horizon_hours}.png"
plot_continuous_vs_event_window(
    continuous_variant=continuous_variant,
    event_feature_key=event_feature_key,
    horizon_hours=horizon_hours,
    start_date=start_date,
    end_date=end_date,
    output_path=plot_path,
)

print(f"Output directory: {output_dir}")
print(f"Plot: {plot_path}")
print(f"Continuous summary CSV: {continuous_csv}")
print(f"Event summary CSV: {event_csv}")

if not continuous_summary.empty:
    display(
        continuous_summary[continuous_summary["horizon_hours"] == horizon_hours]
        .sort_values(["lookback_hours"])
        .reset_index(drop=True)
    )
if not event_summary.empty:
    display(
        event_summary[event_summary["horizon_hours"] == horizon_hours]
        .sort_values(["feature_key", "lookback_hours"])
        .reset_index(drop=True)
    )
# Out:
# Output directory: /home/jovyan/data/lightning/TereziaD/DP_pokracovanieBP/DP_Drengubiakova_Terezia_1/3_vizualizacie/vystupy_nove_data/graf_DST+4
# Plot: /home/jovyan/data/lightning/TereziaD/DP_pokracovanieBP/DP_Drengubiakova_Terezia_1/3_vizualizacie/vystupy_nove_data/graf_DST+4/continuous_vs_event_DST+4.png
# Continuous summary CSV: /home/jovyan/data/lightning/TereziaD/DP_pokracovanieBP/DP_Drengubiakova_Terezia_1/3_vizualizacie/vystupy_nove_data/graf_DST+4/continuous_summary_metrics.csv
# Event summary CSV: /home/jovyan/data/lightning/TereziaD/DP_pokracovanieBP/DP_Drengubiakova_Terezia_1/3_vizualizacie/vystupy_nove_data/graf_DST+4/event_summary_metrics.csv
#         variant  horizon_hours  lookback_hours    rows  mae_persistence  \
# 0  DST+BZ_GSM+V              4               6  194187         6.073218
# 1  DST+BZ_GSM+V              4              12  194181         6.073318
# 2  DST+BZ_GSM+V              4              18  194175         6.073274
# 3  DST+BZ_GSM+V              4              24  194169         6.073117
#
#    mae_lstm  mae_hybrid  rmse_persistence  rmse_lstm  rmse_hybrid  \
# 0  5.352043    5.600902          9.608726   8.159612     8.507945
# 1  5.423658    5.568324          9.608851   8.210712     8.466751
# 2  5.259088    5.607232          9.608881   8.216936     8.583644
# 3  5.286237    5.491000          9.608687   8.145842     8.417081
#
#                                                 path  precision_m20  \
# 0  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.786982
# 1  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.811761
# 2  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.800656
# 3  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.808689
#
#    recall_m20    f1_m20  precision_m50  recall_m50    f1_m50
# 0    0.756741  0.771565       0.758871    0.670825  0.712137
# 1    0.739527  0.773962       0.744373    0.660132  0.699726
# 2    0.735966  0.766949       0.739694    0.681162  0.709222
# 3    0.740084  0.772867       0.736005    0.684192  0.709153
#    feature_key  lookback_hours  horizon_hours   rows  mae_persistence  \
# 0       dst_bz               6              4  22676        10.301729
# 1       dst_bz              12              4  21818        10.468237
# 2       dst_bz              18              4  20960        10.641221
# 3       dst_bz              24              4  20102        10.815143
# 4     dst_bz_v               6              4  22676        10.301729
# 5     dst_bz_v              12              4  21818        10.468237
# 6     dst_bz_v              18              4  20960        10.641221
# 7     dst_bz_v              24              4  20102        10.815143
# 8     dst_only               6              4  22676        10.301729
# 9     dst_only              12              4  21818        10.468237
# 10    dst_only              18              4  20960        10.641221
# 11    dst_only              24              4  20102        10.815143
# 12       dst_v               6              4  15091        10.547677
# 13       dst_v              12              4  20069        10.406398
# 14       dst_v              18              4  18428        10.653571
# 15       dst_v              24              4  16757        10.862983
#
#     mae_bilstm  mae_bilstm_gp  rmse_persistence  rmse_bilstm  rmse_bilstm_gp  \
# 0     9.372087       9.573851         16.532749    14.884519       14.851106
# 1     9.307927       9.683454         16.775116    14.694929       15.072875
# 2     9.544095       9.877271         17.029773    15.207538       15.306429
# 3     9.727504      10.085422         17.293302    15.837808       15.761301
# 4     9.302698       9.486091         16.532749    14.743175       14.705341
# 5     9.323871       9.548180         16.775116    14.609994       14.825424
# 6     9.400003       9.622621         17.029773    14.876535       14.941281
# 7     9.590930       9.959816         17.293302    15.280656       15.603558
# 8     9.647509       9.904044         16.532749    15.275407       15.555534
# 9     9.597541      10.213145         16.775116    15.307928       16.009128
# 10    9.906798      10.196139         17.029773    15.790305       16.111743
# 11    9.975848      10.340541         17.293302    16.176321       15.959076
# 12    9.854602      10.128438         16.869822    16.142448       15.881320
# 13    9.759702      10.296597         16.566931    15.608658       16.141075
# 14    9.962885      10.052207         16.953585    15.791440       15.666245
# 15    9.871737      10.459908         17.277084    16.086578       16.425031
#
#                                                  path  precision_m20  \
# 0   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.894321
# 1   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.904977
# 2   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.904275
# 3   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.907468
# 4   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.895243
# 5   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.905045
# 6   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.908966
# 7   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.906252
# 8   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.890037
# 9   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.900352
# 10  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.896279
# 11  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.868651
# 12  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.894510
# 13  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.901992
# 14  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.901503
# 15  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.905800
#
#     recall_m20    f1_m20  precision_m50  recall_m50    f1_m50
# 0     0.926009  0.909889       0.768990    0.693562  0.729331
# 1     0.924583  0.914675       0.797352    0.681166  0.734694
# 2     0.925410  0.914720       0.794614    0.686603  0.736670
# 3     0.929933  0.918563       0.780876    0.682036  0.728117
# 4     0.925509  0.910124       0.785142    0.703349  0.741998
# 5     0.922309  0.913596       0.792453    0.685080  0.734865
# 6     0.925857  0.917334       0.797575    0.700957  0.746151
# 7     0.922888  0.914494       0.777336    0.723575  0.749493
# 8     0.925634  0.907487       0.776783    0.679643  0.724974
# 9     0.920541  0.910334       0.787503    0.663332  0.720104
# 10    0.927645  0.911693       0.785040    0.687038  0.732777
# 11    0.969491  0.916305       0.836872    0.651588  0.732697
# 12    0.930192  0.912002       0.805164    0.685120  0.740307
# 13    0.921949  0.911861       0.783034    0.667439  0.720631
# 14    0.928104  0.914610       0.798040    0.694129  0.742466
# 15    0.923659  0.914642       0.772715    0.722660  0.746850

# %%
sorted(path.name for path in Path(output_dir).glob("*"))
# Out:
# ['continuous_summary_metrics.csv',
#  'continuous_vs_event_DST+4.png',
#  'event_summary_metrics.csv']
