# %% [markdown]
# # Graf pre DST+3
#
# Notebook porovnava nove kontinualne a event experimenty pre horizont DST+3 v zadanom casovom okne.

# %%
from pathlib import Path

from viz_nove_experimenty import (
    OUTPUT_ROOT,
    plot_continuous_vs_event_window,
    save_continuous_summary_csv,
    save_event_summary_csv,
    summarize_continuous_predictions,
    summarize_event_predictions,
)

# %%
continuous_variant = "DST+BZ_GSM+V"
event_feature_key = "dst_bz_v"
start_date = "2024-12-31"
end_date = "2025-01-03"
horizon_hours = 3

output_dir = OUTPUT_ROOT / "graf_DST+3"
output_dir.mkdir(parents=True, exist_ok=True)
output_dir
# Out:
# PosixPath('/home/jovyan/data/lightning/TereziaD/DP_pokracovanieBP/DP_Drengubiakova_Terezia_1/3_vizualizacie/vystupy_nove_data/graf_DST+3')

# %%
continuous_summary = summarize_continuous_predictions(continuous_variant)
event_summary = summarize_event_predictions()

continuous_csv = None
event_csv = None
if not continuous_summary.empty:
    continuous_csv = save_continuous_summary_csv(continuous_summary, output_dir)
if not event_summary.empty:
    event_csv = save_event_summary_csv(event_summary, output_dir)

plot_path = output_dir / f"continuous_vs_event_DST+{horizon_hours}.png"
plot_continuous_vs_event_window(
    continuous_variant=continuous_variant,
    event_feature_key=event_feature_key,
    horizon_hours=horizon_hours,
    start_date=start_date,
    end_date=end_date,
    output_path=plot_path,
)

print(f"Output directory: {output_dir}")
print(f"Plot: {plot_path}")
print(f"Continuous summary CSV: {continuous_csv}")
print(f"Event summary CSV: {event_csv}")

if not continuous_summary.empty:
    display(
        continuous_summary[continuous_summary["horizon_hours"] == horizon_hours]
        .sort_values(["lookback_hours"])
        .reset_index(drop=True)
    )
if not event_summary.empty:
    display(
        event_summary[event_summary["horizon_hours"] == horizon_hours]
        .sort_values(["feature_key", "lookback_hours"])
        .reset_index(drop=True)
    )
# Out:
# Output directory: /home/jovyan/data/lightning/TereziaD/DP_pokracovanieBP/DP_Drengubiakova_Terezia_1/3_vizualizacie/vystupy_nove_data/graf_DST+3
# Plot: /home/jovyan/data/lightning/TereziaD/DP_pokracovanieBP/DP_Drengubiakova_Terezia_1/3_vizualizacie/vystupy_nove_data/graf_DST+3/continuous_vs_event_DST+3.png
# Continuous summary CSV: /home/jovyan/data/lightning/TereziaD/DP_pokracovanieBP/DP_Drengubiakova_Terezia_1/3_vizualizacie/vystupy_nove_data/graf_DST+3/continuous_summary_metrics.csv
# Event summary CSV: /home/jovyan/data/lightning/TereziaD/DP_pokracovanieBP/DP_Drengubiakova_Terezia_1/3_vizualizacie/vystupy_nove_data/graf_DST+3/event_summary_metrics.csv
#         variant  horizon_hours  lookback_hours    rows  mae_persistence  \
# 0  DST+BZ_GSM+V              3               6  194189         5.299620
# 1  DST+BZ_GSM+V              3              12  194183         5.299650
# 2  DST+BZ_GSM+V              3              18  194177         5.299618
# 3  DST+BZ_GSM+V              3              24  194171         5.299679
#
#    mae_lstm  mae_hybrid  rmse_persistence  rmse_lstm  rmse_hybrid  \
# 0  4.699972    4.902556          8.304162   7.054849     7.351542
# 1  4.620908    4.894192          8.304239   7.010143     7.376004
# 2  4.617193    4.728116          8.304279   7.048053     7.198469
# 3  4.527728    4.713578          8.304373   6.866240     7.117226
#
#                                                 path  precision_m20  \
# 0  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.820791
# 1  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.828453
# 2  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.847064
# 3  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.846658
#
#    recall_m20    f1_m20  precision_m50  recall_m50    f1_m50
# 0    0.787264  0.803678       0.784302    0.721262  0.751462
# 1    0.774869  0.800765       0.800000    0.701479  0.747507
# 2    0.766039  0.804517       0.789760    0.750490  0.769624
# 3    0.773207  0.808267       0.778031    0.730886  0.753722
#    feature_key  lookback_hours  horizon_hours   rows  mae_persistence  \
# 0       dst_bz               6              3  22676         8.866334
# 1       dst_bz              12              3  21818         9.003942
# 2       dst_bz              18              3  20960         9.150239
# 3       dst_bz              24              3  20102         9.299970
# 4     dst_bz_v               6              3  22676         8.866334
# 5     dst_bz_v              12              3  21818         9.003942
# 6     dst_bz_v              18              3  20960         9.150239
# 7     dst_bz_v              24              3  20102         9.299970
# 8     dst_only               6              3  22676         8.866334
# 9     dst_only              12              3  21818         9.003942
# 10    dst_only              18              3  20960         9.150239
# 11    dst_only              24              3  20102         9.299970
# 12       dst_v               6              3  15091         9.074614
# 13       dst_v              12              3  20069         8.959440
# 14       dst_v              18              3  18429         9.169624
# 15       dst_v              24              3  16757         9.358417
#
#     mae_bilstm  mae_bilstm_gp  rmse_persistence  rmse_bilstm  rmse_bilstm_gp  \
# 0     8.397439       8.132223         14.128525    13.101051       12.750479
# 1     8.305713       8.249901         14.329091    12.802832       12.765388
# 2     8.603357       8.546436         14.542880    13.419771       13.215119
# 3     8.458409       8.834851         14.763334    13.581668       14.003625
# 4     8.299934       8.067541         14.128525    12.901362       12.664444
# 5     8.404941       8.083212         14.329091    12.800048       12.456723
# 6     8.341781       8.376955         14.542880    12.957268       12.831261
# 7     8.599150       8.650564         14.763334    13.383321       13.547137
# 8     8.700791       8.761660         14.128525    13.497431       13.778287
# 9     8.621076       8.732232         14.329091    13.470931       13.634453
# 10    8.951420       8.994688         14.542880    14.016877       13.987499
# 11    8.943670       9.283454         14.763334    14.209377       14.532593
# 12    8.850318       8.725481         14.407801    14.205922       13.835845
# 13    8.678393       8.695524         14.169755    13.509167       13.479572
# 14    8.995025       8.893012         14.503809    14.030616       13.719320
# 15    8.784007       9.282441         14.782760    14.083925       14.770511
#
#                                                  path  precision_m20  \
# 0   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.920922
# 1   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.918152
# 2   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.920718
# 3   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.928470
# 4   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.924072
# 5   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.919570
# 6   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.923811
# 7   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.926557
# 8   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.911985
# 9   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.917059
# 10  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.914191
# 11  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.919797
# 12  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.920238
# 13  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.920280
# 14  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.919630
# 15  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.923886
#
#     recall_m20    f1_m20  precision_m50  recall_m50    f1_m50
# 0     0.927098  0.924000       0.831381    0.741136  0.783669
# 1     0.930368  0.924220       0.810507    0.751795  0.780047
# 2     0.936403  0.928494       0.809906    0.747009  0.777187
# 3     0.928951  0.928710       0.812085    0.745486  0.777362
# 4     0.922334  0.923202       0.843216    0.730041  0.782558
# 5     0.931572  0.925532       0.810936    0.761366  0.785370
# 6     0.935763  0.929749       0.804627    0.748967  0.775800
# 7     0.924154  0.925354       0.821504    0.757886  0.788414
# 8     0.922961  0.917440       0.829025    0.704590  0.761759
# 9     0.926123  0.921569       0.787003    0.740265  0.762919
# 10    0.936147  0.925039       0.812196    0.727213  0.767359
# 11    0.928562  0.924159       0.798124    0.740483  0.768224
# 12    0.921757  0.920997       0.836358    0.756226  0.794276
# 13    0.930429  0.925327       0.806012    0.739685  0.771425
# 14    0.933170  0.926350       0.804884    0.733602  0.767592
# 15    0.929195  0.926533       0.816778    0.755791  0.785102

# %%
sorted(path.name for path in Path(output_dir).glob("*"))
# Out:
# ['continuous_summary_metrics.csv',
#  'continuous_vs_event_DST+3.png',
#  'event_summary_metrics.csv']
