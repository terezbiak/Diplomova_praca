# %% [markdown]
# # Graf pre DST+2
#
# Notebook porovnava nove kontinualne a event experimenty pre horizont DST+2 v zadanom casovom okne.

# %%
from pathlib import Path

from viz_nove_experimenty import (
    OUTPUT_ROOT,
    plot_continuous_vs_event_window,
    save_continuous_summary_csv,
    save_event_summary_csv,
    summarize_continuous_predictions,
    summarize_event_predictions,
)

# %%
continuous_variant = "DST+BZ_GSM+V"
event_feature_key = "dst_bz_v"
start_date = "2024-12-31"
end_date = "2025-01-03"
horizon_hours = 2

output_dir = OUTPUT_ROOT / "graf_DST+2"
output_dir.mkdir(parents=True, exist_ok=True)
output_dir
# Out:
# PosixPath('/home/jovyan/data/lightning/TereziaD/DP_pokracovanieBP/DP_Drengubiakova_Terezia_1/3_vizualizacie/vystupy_nove_data/graf_DST+2')

# %%
continuous_summary = summarize_continuous_predictions(continuous_variant)
event_summary = summarize_event_predictions()

continuous_csv = None
event_csv = None
if not continuous_summary.empty:
    continuous_csv = save_continuous_summary_csv(continuous_summary, output_dir)
if not event_summary.empty:
    event_csv = save_event_summary_csv(event_summary, output_dir)

plot_path = output_dir / f"continuous_vs_event_DST+{horizon_hours}.png"
plot_continuous_vs_event_window(
    continuous_variant=continuous_variant,
    event_feature_key=event_feature_key,
    horizon_hours=horizon_hours,
    start_date=start_date,
    end_date=end_date,
    output_path=plot_path,
)

print(f"Output directory: {output_dir}")
print(f"Plot: {plot_path}")
print(f"Continuous summary CSV: {continuous_csv}")
print(f"Event summary CSV: {event_csv}")

if not continuous_summary.empty:
    display(
        continuous_summary[continuous_summary["horizon_hours"] == horizon_hours]
        .sort_values(["lookback_hours"])
        .reset_index(drop=True)
    )
if not event_summary.empty:
    display(
        event_summary[event_summary["horizon_hours"] == horizon_hours]
        .sort_values(["feature_key", "lookback_hours"])
        .reset_index(drop=True)
    )
# Out:
# Output directory: /home/jovyan/data/lightning/TereziaD/DP_pokracovanieBP/DP_Drengubiakova_Terezia_1/3_vizualizacie/vystupy_nove_data/graf_DST+2
# Plot: /home/jovyan/data/lightning/TereziaD/DP_pokracovanieBP/DP_Drengubiakova_Terezia_1/3_vizualizacie/vystupy_nove_data/graf_DST+2/continuous_vs_event_DST+2.png
# Continuous summary CSV: /home/jovyan/data/lightning/TereziaD/DP_pokracovanieBP/DP_Drengubiakova_Terezia_1/3_vizualizacie/vystupy_nove_data/graf_DST+2/continuous_summary_metrics.csv
# Event summary CSV: /home/jovyan/data/lightning/TereziaD/DP_pokracovanieBP/DP_Drengubiakova_Terezia_1/3_vizualizacie/vystupy_nove_data/graf_DST+2/event_summary_metrics.csv
#         variant  horizon_hours  lookback_hours    rows  mae_persistence  \
# 0  DST+BZ_GSM+V              2               6  194191         4.211529
# 1  DST+BZ_GSM+V              2              12  194185         4.211535
# 2  DST+BZ_GSM+V              2              18  194179         4.211526
# 3  DST+BZ_GSM+V              2              24  194173         4.211590
#
#    mae_lstm  mae_hybrid  rmse_persistence  rmse_lstm  rmse_hybrid  \
# 0  3.649597    3.768530          6.576884   5.469958     5.688656
# 1  3.626103    3.742001          6.576930   5.541396     5.718136
# 2  3.614835    3.789723          6.576967   5.475799     5.682242
# 3  3.617901    3.789883          6.577055   5.400028     5.649925
#
#                                                 path  precision_m20  \
# 0  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.870557
# 1  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.870245
# 2  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.877274
# 3  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.884029
#
#    recall_m20    f1_m20  precision_m50  recall_m50    f1_m50
# 0    0.830679  0.850151       0.846668    0.790233  0.817478
# 1    0.834635  0.852068       0.830334    0.805917  0.817943
# 2    0.816264  0.845670       0.835443    0.799857  0.817263
# 3    0.805511  0.842946       0.831765    0.787738  0.809153
#    feature_key  lookback_hours  horizon_hours   rows  mae_persistence  \
# 0       dst_bz               6              2  22676         6.995017
# 1       dst_bz              12              2  21818         7.098084
# 2       dst_bz              18              2  20960         7.210496
# 3       dst_bz              24              2  20102         7.328425
# 4     dst_bz_v               6              2  22676         6.995017
# 5     dst_bz_v              12              2  21818         7.098084
# 6     dst_bz_v              18              2  20960         7.210496
# 7     dst_bz_v              24              2  20102         7.328425
# 8     dst_only               6              2  22676         6.995017
# 9     dst_only              12              2  21818         7.098084
# 10    dst_only              18              2  20960         7.210496
# 11    dst_only              24              2  20102         7.328425
# 12       dst_v               6              2  15091         7.149427
# 13       dst_v              12              2  20069         7.073148
# 14       dst_v              18              2  18429         7.237452
# 15       dst_v              24              2  16758         7.392589
#
#     mae_bilstm  mae_bilstm_gp  rmse_persistence  rmse_bilstm  rmse_bilstm_gp  \
# 0     7.084927       6.467468         11.078006    10.832824       10.095609
# 1     6.882305       6.474051         11.230075    10.365735       10.033544
# 2     7.244187       6.496979         11.395740    11.075045       10.043669
# 3     7.163831       7.085853         11.567961    11.324753       10.901951
# 4     6.971846       6.383570         11.078006    10.635792        9.940861
# 5     7.039024       7.086668         11.230075    10.401214       10.395817
# 6     6.971856       6.380513         11.395740    10.603494        9.855437
# 7     7.100366       7.177861         11.567961    10.886464       10.844388
# 8     7.406474       6.965552         11.078006    11.201655       10.907997
# 9     7.322577       7.000102         11.230075    11.135958       10.988557
# 10    7.627409       7.288211         11.395740    11.704093       11.373822
# 11    7.418550       7.501399         11.567961    11.565193       11.509635
# 12    7.410215       7.100480         11.257229    11.720571       11.216928
# 13    7.271340       7.316332         11.106636    11.128270       11.125073
# 14    7.665122       7.179053         11.370045    11.776288       11.084105
# 15    7.301765       7.399831         11.596168    11.598573       11.447231
#
#                                                  path  precision_m20  \
# 0   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.935912
# 1   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.945856
# 2   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.942636
# 3   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.938864
# 4   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.937029
# 5   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.918013
# 6   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.939223
# 7   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.909910
# 8   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.928005
# 9   /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.938273
# 10  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.934997
# 11  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.931121
# 12  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.936121
# 13  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.932699
# 14  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.935424
# 15  /home/jovyan/data/lightning/TereziaD/DP_pokrac...       0.915492
#
#     recall_m20    f1_m20  precision_m50  recall_m50    f1_m50
# 0     0.944560  0.940216       0.877607    0.768980  0.819710
# 1     0.934973  0.940383       0.877155    0.785947  0.829050
# 2     0.946814  0.944720       0.871408    0.791603  0.829591
# 3     0.945517  0.942179       0.872763    0.774418  0.820655
# 4     0.945628  0.941309       0.877728    0.769850  0.820257
# 5     0.960844  0.938940       0.894819    0.751360  0.816838
# 6     0.949961  0.944562       0.878686    0.797259  0.835995
# 7     0.978415  0.942920       0.905479    0.758538  0.825521
# 8     0.941480  0.934694       0.864282    0.767457  0.812997
# 9     0.935291  0.936780       0.860707    0.772895  0.814441
# 10    0.943345  0.939153       0.860323    0.765064  0.809902
# 11    0.941291  0.936178       0.832868    0.778334  0.804678
# 12    0.936380  0.936250       0.877693    0.775857  0.823639
# 13    0.944482  0.938554       0.849133    0.782800  0.814618
# 14    0.945578  0.940474       0.858991    0.786171  0.820969
# 15    0.973181  0.943455       0.888858    0.782405  0.832241

# %%
sorted(path.name for path in Path(output_dir).glob("*"))
# Out:
# ['.ipynb_checkpoints',
#  'continuous_summary_metrics.csv',
#  'continuous_vs_event_DST+2.png',
#  'event_summary_metrics.csv']
